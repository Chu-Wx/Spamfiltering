# %%
# !wget 'https://docs.google.com/uc?export=download&id=1OVRo37agn02mc6yp5p6-wtJ8Hyb-YMXR' -O spam.csv
# Out:
# --2021-02-10 13:13:26--  https://docs.google.com/uc?export=download&id=1OVRo37agn02mc6yp5p6-wtJ8Hyb-YMXR
# Resolving docs.google.com (docs.google.com)... 2607:f8b0:4006:818::200e, 172.217.12.174
# Connecting to docs.google.com (docs.google.com)|2607:f8b0:4006:818::200e|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-04-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ohv0p54696982mlplsge3sg6308u7sqn/1612980750000/08752484438609855375/*/1OVRo37agn02mc6yp5p6-wtJ8Hyb-YMXR?e=download [following]
# ...
# --2021-02-10 13:13:27--  https://doc-14-04-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/ohv0p54696982mlplsge3sg6308u7sqn/1612980750000/08752484438609855375/*/1OVRo37agn02mc6yp5p6-wtJ8Hyb-YMXR?e=download
# Resolving doc-14-04-docs.googleusercontent.com (doc-14-04-docs.googleusercontent.com)... 2607:f8b0:4006:802::2001, 142.250.64.97
# ...

# %%
# !ls
# Out:
# AT.postflight.17002            Prediction Curve-Confirmed.png
# Applications                   Prediction Curve2.png
# COIVD-19-World.png             Public
# Covid-19 Viz & Predic.ipynb    Untitled.ipynb
# Desktop                        iCloud Drive (Archive)
# Documents                      model_confirmed.h5
# Downloads                      model_confirmed_v4.h5
# Library                        model_deaths.h5
# MLLU HW1-Chuwei Xu.ipynb       model_deaths_v5.h5
# Movies                         spam.csv
# Music                          spread.png
# Pictures                       tmp

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("spam.csv", usecols=["v1", "v2"], encoding='latin-1')
# 1 - spam, 0 - ham
df.v1 = (df.v1 == "spam").astype("int")
df.head()
# Out:
# /Users/user/.pyenv/versions/3.7.5/lib/python3.7/site-packages/pandas/compat/__init__.py:117: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
#    v1                                                 v2
# 0   0  Go until jurong point, crazy.. Available only ...
# 1   0                      Ok lar... Joking wif u oni...
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   0  U dun say so early hor... U c already then say...
# 4   0  Nah I don't think he goes to usf, he lives aro...

# %%
# 0.15 for val, 0.15 for test, 0.7 for train
val_size = int(df.shape[0] * 0.15)
test_size = int(df.shape[0] * 0.15)

train_size= int(df.shape[0]*0.7)
df=df.sample(frac=1)
valcol=df['v2'].tolist()[int(0.7*df.shape[0]):int(0.85*df.shape[0])]
testcol=df['v2'].tolist()[int(0.85*df.shape[0]):]
traincol=df['v2'].tolist()[:int(0.7*df.shape[0])]
Array={'val_size':valcol,'test_size':testcol,'train_size':traincol}
print(Array)

train_texts, train_labels = traincol, df['v1'].tolist()[:int(0.7*df.shape[0])]
val_texts, val_labels     = valcol, df['v1'].tolist()[int(0.7*df.shape[0]):int(0.85*df.shape[0])]
test_texts, test_labels   = testcol, df['v1'].tolist()[int(0.85*df.shape[0]):]
# Out:
# {'val_size': ["Don't make life too stressfull.. Always find time to Laugh.. It may not add years to your Life! But surely adds more life to ur years!! Gud ni8..swt dreams..", 'Or I guess  &lt;#&gt;  min', "Anyway I don't think I can secure anything up here, lemme know if you want me to drive down south and chill", "Sorry, I can't text &amp; drive coherently, see you in twenty", 'Waiting 4 my tv show 2 start lor... U leh still busy doing ur report?', 'Ok., is any problem to u frm him? Wats matter?', 'Good FRIENDS CaRE for each Other.. CLoSE Friends UNDERSTaND each Other... and TRUE Friends STaY forever beyond words, beyond time. Gud ni8', 'PS U no ur a grown up now right?', 'Hi Chachi tried calling u now unable to reach u .. Pl give me a missed cal once u c tiz msg  Kanagu', 'Babes I think I got ur brolly I left it in English wil bring it in 2mrw 4 u luv Franxx', 'A swt thought: \\Nver get tired of doing little things 4 lovable persons..\\" Coz..somtimes those little things occupy d b
# ...

# %%
def preprocess_data(data):
    # This function should return a list of lists of pre-processed tokens, where
    # each nested list contains the tokens for a single message. To pre-process
    # each message, tokenize the message and lowercase all text.
    import spacy as sc
    import string
    nlp = sc.load("en_core_web_sm")
    stopwords=nlp.Defaults.stop_words
    List=[]
    for i in data:
      token = [token.text.lower() for token in nlp(i)]
      List_without_sw=[j for j in token if not j in stopwords]
      List.append(List_without_sw)

    preprocessed_data = List
    return preprocessed_data

train_data = preprocess_data(train_texts)
val_data = preprocess_data(val_texts)
test_data = preprocess_data(test_texts)

# %%
train_data
# Out:
# [['way', ',', "'", 'rencontre', "'", 'meet', '.', 'mountains', 'nt', '....'],
#  ['pls', 'come', 'quick', 'nt', 'bare', '.'],
#  ['freemsg',
#   ':',
#   'records',
#   'indicate',
#   'entitled',
#   '3750',
#   'pounds',
#   'accident',
#   '.',
#   'claim',
#   'free',
#   'reply',
#   'yes',
#   'msg',
#   '.',
#   'opt',
#   'text',
#   'stop'],
#  ['dled', '3d', 'imp'],
#  ['coffee', 'cake', ',', 'guess', '...'],
#  ['different', 'styles', '?'],
#  ['famous',
#   'quote',
#   ':',
#   'develop',
#   'ability',
#   'listen',
#   "'",
#   "'",
#   'unconditionally',
#   'losing',
#   'temper',
#   'self',
#   'confidence',
#   ',',
#   'means',
#   '.........',
#   "'",
#   'married',
#   "'"],
#  ['fret',
#   '.',
#   'buy',
#   'ovulation',
#   'test',
#   'strips',
#   'send',
#   '.',
#   'wo',
#   'nt',
#   'til',
#   'like',
#   'march',
#   '.',
#   'send',
#   'postal',
#   "address.u'll",
#   'alright',
#   '.',
#   'okay',
#   '.'],
#  ['fighting',
#   'world',
# ...

# %%
import numpy as np

class Vectorizer():
    def __init__(self, max_features):
        self.max_features = max_features
        self.vocab_list = None
        self.token_to_index = None

    def fit(self, dataset):
        # Given a list of lists of tokens, create a vocab list, self.vocab_list, 
        # using the most frequent "max_features" tokens. Also create a token 
        # indexer, self.token_to_index, that will return the index of the token 
        # in self.vocab_list.
        from collections import Counter
        Commonlist=(words for line in dataset for words in line)
        tokenlist = Counter(Commonlist)
        Mostcommonword=tokenlist.most_common(max_features)
        self.vocab_list=[i[0] for i in Mostcommonword]
        self.token_to_index={value : index for index, value in enumerate(self.vocab_list)}
          

    def transform(self, dataset):
        # This function transforms the text dataset (a list of lists of tokens) 
        # into a matrix, "data_matrix," where the entry located at (i, j) is 1 
        # if sample i of the dataset contains token j in the vocab list, and 0 
        # otherwise.
        data_matrix = np.zeros((len(dataset), len(self.vocab_list)))
        for line_index, line in enumerate(dataset):
          for word_index, word in enumerate(line):
            if word in self.vocab_list:
              word_pos=dataset[line_index][word_index]
              data_matrix[line_index,self.token_to_index[word_pos]]=1
        
        return data_matrix

# %%
max_features = 400 # TODO: Replace None with a number
vectorizer = Vectorizer(max_features=max_features)
vectorizer.fit(train_data)
X_train = vectorizer.transform(train_data)
X_val = vectorizer.transform(val_data)
X_test = vectorizer.transform(test_data)

y_train = np.array(train_labels)
y_val = np.array(val_labels)
y_test = np.array(test_labels)

vocab = vectorizer.vocab_list

# %%
# More features to matrix
"""
#added features: remove puncuation (RISK: might or might not decrease the accuracy of the model, depend the "spam word" quantities)
class textcleaner():
  def __init__(self,max_features):
    self.max_features = max_features
    self.cleantext_list = None
  def clean(self,dataset):
    from collections import Counter
    Commonlist=(words for line in dataset for words in line)
    tokenlist = Counter(Commonlist)
    Mostcommonword=tokenlist.most_common(max_features)
    self.vocab_list=[i[0] for i in Mostcommonword]
    cleantext_list=[word.translate(str.maketrans('','',string.punctuation))for word in self.vocab_list]"""
# Out:
# '\n#added features: remove puncuation (RISK: might or might not decrease the accuracy of the model, depend the "spam word" quantities)\nclass textcleaner():\n  def __init__(self,max_features):\n    self.max_features = max_features\n    self.cleantext_list = None\n  def clean(self,dataset):\n    from collections import Counter\n    Commonlist=(words for line in dataset for words in line)\n    tokenlist = Counter(Commonlist)\n    Mostcommonword=tokenlist.most_common(max_features)\n    self.vocab_list=[i[0] for i in Mostcommonword]\n    cleantext_list=[word.translate(str.maketrans(\'\',\'\',string.punctuation))for word in self.vocab_list]'

# %%
from sklearn.linear_model import LogisticRegression

# Define Logistic Regression model
model = LogisticRegression(random_state=0, solver='liblinear')

# Fit the model to training data
model.fit(X_train, y_train)

# Make prediction using the trained model
y_train_pred = model.predict(X_train)
y_val_pred = model.predict(X_val)
y_test_pred = model.predict(X_test)

# %%
def accuracy_score(y_true, y_pred): 
    # Calculate accuracy of the model's prediction
    tp,tn,fp,fn=0,0,0,0
    for i, j in zip(y_pred,y_true):
      if i==j and i !=0:
        tp+=1
      elif i==j and i==0:
        tn+=1
      elif i-j==-1:
        fn+=1
      elif i-j==1:
        fp+=1
    
    accuracy = (tn+tp)/(tp+tn+fp+fn)
    return accuracy

def f1_score(y_true, y_pred): 
    # Calculate F1 score of the model's prediction
    tp,tn,fp,fn=0,0,0,0
    for i, j in zip(y_pred,y_true):
      if i==j and i !=0:
        tp+=1
      elif i==j and i==0:
        tn+=1
      elif i-j==-1:
        fn+=1
      elif i-j==1:
        fp+=1
    recall=tp/(tp+fn)
    precision=tp/(tp+fp)

    f1 = 2*(precision*recall)/(precision+recall)
    return f1

# %%
print(f"Training accuracy: {accuracy_score(y_train, y_train_pred):.3f}, "
      f"F1 score: {f1_score(y_train, y_train_pred):.3f}")
print(f"Validation accuracy: {accuracy_score(y_val, y_val_pred):.3f}, "
      f"F1 score: {f1_score(y_val, y_val_pred):.3f}")
print(f"Test accuracy: {accuracy_score(y_test, y_test_pred):.3f}, "
      f"F1 score: {f1_score(y_test, y_test_pred):.3f}")
# Out:
# Training accuracy: 0.986, F1 score: 0.945
# Validation accuracy: 0.972, F1 score: 0.886
# Test accuracy: 0.978, F1 score: 0.920

# %% [raw]
# Question. Is accuracy the metric that logistic regression optimizes while training? If no, which metric is optimized in logistic regression?
#
# Your answer:the accuracy of the trainning and validation are close which means the model not underfitting nor overfitting the dataset. the accuracy is optimizes.

# %% [raw]
# Question. In general, does having 0.99 accuracy on test means that the model is great? If no, can you give an example of a case when the accuracy is high but the model is not good? (Hint: why do we use F1 score?)
#
# Your answer:0.99 accuracy does not mean the model is great. for exmaple, if we have 30 patient who has cancer but only 27 are found by the model, which means 3 true patients will not get treated, but the accuracy is a high 90%. This is why use f1 score which cares more about the false negative and false positive in the dataset. If f1 is lower, means the error is greater (the false nagative has greater portion in dataset)

# %%
#correctly predicted email
for i,j in enumerate(y_val_pred[11:13]):
  for k,value in enumerate(df.values.tolist()[int(0.7*df.shape[0]):int(0.85*df.shape[0])][10:30]):
      if value[0]==j:
        if j==1: 
          print('Predicted Value:',j,"Real Value:",value)
        else:
          print('Predicted Value:',j,"Real Value:",value)
#correctly predicted email trainsets
for i,j in enumerate(y_train_pred[2:4]):
  for k,value in enumerate(df.values.tolist()[:int(0.7*df.shape[0])][:4]):
      if value[0]==j:
        if j==1: 
          print('Predicted Value:',j,"Real Value:",value)
        else:
          print('Predicted Value:',j,"Real Value:",value)
# 1 - spam, 0 - ham
# Out:
# Predicted Value: 0 Real Value: [0, 'A swt thought: \\Nver get tired of doing little things 4 lovable persons..\\" Coz..somtimes those little things occupy d biggest part in their Hearts.. Gud ni8"']
# Predicted Value: 0 Real Value: [0, 'Uhhhhrmm isnt having tb test bad when youre sick']
# Predicted Value: 0 Real Value: [0, 'My battery is low babe']
# Predicted Value: 0 Real Value: [0, 'ÌÏ go home liao? Ask dad to pick me up at 6...']
# Predicted Value: 0 Real Value: [0, 'In case you wake up wondering where I am, I forgot I have to take care of something for grandma today, should be done before the parade']
# Predicted Value: 0 Real Value: [0, "Can you please send me my aunty's number"]
# Predicted Value: 0 Real Value: [0, "My computer just fried the only essential part we don't keep spares of because my fucking idiot roommates looovvve leaving the thing running on full  &lt;#&gt; /7"]
# Predicted Value: 0 Real Value: [0, 'Where @']
# ...

# %% [raw]
# Question Print 10 examples from val set which were labeled incorrectly by the model. Why do you think the model got them wrong?
#
# Your answer:the criteria of filtering is not enough which means the vocab list is not 'fully loaded', and it also means our trainning is not enough. on the other hand, the words in spam has high occurance possiblity in vocab list because expect some words with puncuation in, most of it looks like a legit email words.

# %%
count=0
for i,j in enumerate(y_val_pred):
  for k,value in enumerate(df.values.tolist()[int(0.7*df.shape[0]):int(0.85*df.shape[0])]):
    if value[0]!=j and count <10:
            print('Predicted Value:',j,"Real Value:",value)
            count+=1
# Out:
# Predicted Value: 0 Real Value: [1, 'Do you want a NEW video phone750 anytime any network mins 150 text for only five pounds per week call 08000776320 now or reply for delivery tomorrow']
# Predicted Value: 0 Real Value: [1, 'Hi 07734396839 IBH Customer Loyalty Offer: The NEW NOKIA6600 Mobile from ONLY å£10 at TXTAUCTION!Txt word:START to No:81151 & get Yours Now!4T&']
# Predicted Value: 0 Real Value: [1, 'You are a winner you have been specially selected to receive å£1000 cash or a å£2000 award. Speak to a live operator to claim call 087147123779am-7pm. Cost 10p']
# Predicted Value: 0 Real Value: [1, '4mths half price Orange line rental & latest camera phones 4 FREE. Had your phone 11mths ? Call MobilesDirect free on 08000938767 to update now! or2stoptxt']
# Predicted Value: 0 Real Value: [1, 'Camera - You are awarded a SiPix Digital Camera! call 09061221066 fromm landline. Delivery within 28 days']
# ...
